# %%
cd dataset
# Out:
# C:\Users\Miya\Desktop\cna\dataset

# %%
import py2neo
py2neo.__version__
# Out:
# '2.0.9'

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv('repositories_refined.csv',parse_dates=['Month, Day, Year of Date'])
#data = data[data['Coding Effort']!=0]
data.columns= ['Worker ID','Repository ID','Coding Effort','Month, Day, Year of Date']

# %%
from networkx.algorithms import bipartite
agg = data.groupby(['Worker ID','Repository ID']).sum().reset_index()
G = nx.Graph()
for i,v,j in zip(agg['Worker ID'],agg['Repository ID'],agg['Coding Effort']):
    G.add_edge(i,v,weight = j)
W = bipartite.collaboration_weighted_projected_graph(G, data['Worker ID'])

# %%
df_Degree = pd.DataFrame.from_dict({'Worker ID':list(nx.degree(G).keys()),'Number of Projects':list(nx.degree(G).values())})
df_scatter = data.groupby('Worker ID').sum().reset_index().merge(df_Degree).set_index('Worker ID')
df_collaborative = data.groupby(['Worker ID','Repository ID']).sum().reset_index()
df_collaborative = df_collaborative[df_collaborative['Worker ID'].isin(df_scatter[(df_scatter['Number of Projects']>=0) 
                                                                    & (df_scatter['Number of Projects']<=50)].reset_index()['Worker ID'])]

# %%
df_collaborative.head()
# Out:
#   Worker ID Repository ID  Coding Effort
# 0       aaa           AAA           0.00
# 1       aah           KNU           0.00
# 2       aaj           NLY          70.05
# 3       aaq           LZH         122.94
# 4       aaq           QGX           0.00

# %% [markdown]
# ## Neo4j

# %% [markdown]
# ### A. Developer-Developer

# %%
from py2neo import Graph
graph = Graph('http://neo4j:neo4j@localhost:7474/db/data/')

tx = graph.cypher.begin()

W_df = pd.DataFrame(W.edges(),columns = ['Worker1','Worker2'])
statement = "MERGE (a:`Worker`{worker_id:{A}}) RETURN a"
for u in W_df['Worker1'].unique():
    tx.append(statement, {"A": u})

tx.commit()
# Out:
#    | a
# ---+-----------------------------------
#  1 | (n50739:Worker {worker_id:"rra"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49023:Worker {worker_id:"ant"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49981:Worker {worker_id:"jyr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49700:Worker {worker_id:"hia"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50309:Worker {worker_id:"new"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51399:Worker {worker_id:"ylp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51323:Worker {worker_id:"xso"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51432:Worker {worker_id:"yuf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50525:Worker {worker_id:"pjl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49653:Worker {worker_id:"gvc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50077:Worker {worker_id:"kxg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49028:Worker {worker_id:"aol"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49501:Worker {worker_id:"fhp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51139:Worker {worker_id:"vuj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51253:Worker {worker_id:"xab"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51443:Worker {worker_id:"ywe"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50238:Worker {worker_id:"mpl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51458:Worker {worker_id:"zap"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51536:Worker {worker_id:"zws"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50351:Worker {worker_id:"npi"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49747:Worker {worker_id:"hse"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49368:Worker {worker_id:"dwh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51087:Worker {worker_id:"vdj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50764:Worker {worker_id:"rxr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50736:Worker {worker_id:"rqs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51113:Worker {worker_id:"voi"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49078:Worker {worker_id:"bdn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49017:Worker {worker_id:"amp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50328:Worker {worker_id:"njf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49040:Worker {worker_id:"aqp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50269:Worker {worker_id:"mvo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49681:Worker {worker_id:"hdg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n14068:Worker {worker_id:"ard"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50741:Worker {worker_id:"rri"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50692:Worker {worker_id:"rdn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51265:Worker {worker_id:"xev"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49496:Worker {worker_id:"fgi"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51013:Worker {worker_id:"ulp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50480:Worker {worker_id:"oxv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50800:Worker {worker_id:"shg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48203:Worker {worker_id:"ola"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51004:Worker {worker_id:"uji"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51185:Worker {worker_id:"wgu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50909:Worker {worker_id:"thq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51164:Worker {worker_id:"wan"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50231:Worker {worker_id:"mml"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49207:Worker {worker_id:"ckm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49401:Worker {worker_id:"eev"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49753:Worker {worker_id:"htt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51211:Worker {worker_id:"wop"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49165:Worker {worker_id:"cam"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50289:Worker {worker_id:"mzs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49242:Worker {worker_id:"csg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49540:Worker {worker_id:"frd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49545:Worker {worker_id:"fsc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49558:Worker {worker_id:"fuv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49967:Worker {worker_id:"juk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51480:Worker {worker_id:"zhg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49758:Worker {worker_id:"hvb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51079:Worker {worker_id:"vbu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49181:Worker {worker_id:"cem"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50009:Worker {worker_id:"kfg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50058:Worker {worker_id:"ksb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49432:Worker {worker_id:"elt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49460:Worker {worker_id:"eyj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50405:Worker {worker_id:"occ"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49683:Worker {worker_id:"hdu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50003:Worker {worker_id:"kdb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50167:Worker {worker_id:"lvm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49298:Worker {worker_id:"dfb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49246:Worker {worker_id:"ctd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49202:Worker {worker_id:"cjq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51501:Worker {worker_id:"znd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50131:Worker {worker_id:"lmx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51033:Worker {worker_id:"uqe"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51461:Worker {worker_id:"zbz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49398:Worker {worker_id:"eej"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50575:Worker {worker_id:"pxb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50085:Worker {worker_id:"kyw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51279:Worker {worker_id:"xiq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50532:Worker {worker_id:"pma"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50033:Worker {worker_id:"kkm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50994:Worker {worker_id:"uen"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49029:Worker {worker_id:"aor"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51531:Worker {worker_id:"zva"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50098:Worker {worker_id:"ldm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50113:Worker {worker_id:"lif"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49413:Worker {worker_id:"eiq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51293:Worker {worker_id:"xle"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49377:Worker {worker_id:"eaa"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49737:Worker {worker_id:"hqx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49106:Worker {worker_id:"bjz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51005:Worker {worker_id:"ukf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51189:Worker {worker_id:"wht"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49234:Worker {worker_id:"cpj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51103:Worker {worker_id:"vkn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50822:Worker {worker_id:"sly"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50139:Worker {worker_id:"lod"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49039:Worker {worker_id:"aqo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50316:Worker {worker_id:"ngo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51425:Worker {worker_id:"yry"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49815:Worker {worker_id:"ihr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50202:Worker {worker_id:"mfo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50972:Worker {worker_id:"tww"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49024:Worker {worker_id:"anu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51073:Worker {worker_id:"var"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51057:Worker {worker_id:"uwe"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50717:Worker {worker_id:"rnk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49082:Worker {worker_id:"bee"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48982:Worker {worker_id:"aem"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50096:Worker {worker_id:"lav"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49721:Worker {worker_id:"hnk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49760:Worker {worker_id:"hwh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49051:Worker {worker_id:"avf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50976:Worker {worker_id:"tzp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50598:Worker {worker_id:"qbq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49465:Worker {worker_id:"ezh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50164:Worker {worker_id:"lun"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51362:Worker {worker_id:"ycf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49286:Worker {worker_id:"dbs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49043:Worker {worker_id:"arg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50915:Worker {worker_id:"tjm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49430:Worker {worker_id:"elm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49706:Worker {worker_id:"hjt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49104:Worker {worker_id:"bjt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50349:Worker {worker_id:"npb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48998:Worker {worker_id:"aic"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51227:Worker {worker_id:"wsy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49513:Worker {worker_id:"flc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49434:Worker {worker_id:"emc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n47638:Worker {worker_id:"feb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50735:Worker {worker_id:"rqp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49387:Worker {worker_id:"eck"})
#
#    | a
# ---+-----------------------------------
#  1 | (n47367:Worker {worker_id:"ebd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50300:Worker {worker_id:"nct"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49511:Worker {worker_id:"fko"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50184:Worker {worker_id:"mah"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50937:Worker {worker_id:"tpd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50601:Worker {worker_id:"qck"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51134:Worker {worker_id:"vth"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49392:Worker {worker_id:"edc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50982:Worker {worker_id:"uay"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49050:Worker {worker_id:"auw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51207:Worker {worker_id:"wnj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50470:Worker {worker_id:"oux"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50961:Worker {worker_id:"tux"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49865:Worker {worker_id:"iwa"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51391:Worker {worker_id:"yjx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50338:Worker {worker_id:"nlx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49500:Worker {worker_id:"fhj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49203:Worker {worker_id:"cjv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50616:Worker {worker_id:"qgo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51541:Worker {worker_id:"zyt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51014:Worker {worker_id:"ulr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50399:Worker {worker_id:"obu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50193:Worker {worker_id:"mdq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51417:Worker {worker_id:"yql"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49168:Worker {worker_id:"cbd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n47403:Worker {worker_id:"ulc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49070:Worker {worker_id:"bbt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51302:Worker {worker_id:"xoa"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51470:Worker {worker_id:"zel"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50673:Worker {worker_id:"qvy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49973:Worker {worker_id:"jwg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50456:Worker {worker_id:"orr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49912:Worker {worker_id:"jgx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49364:Worker {worker_id:"duv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49679:Worker {worker_id:"hcs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49901:Worker {worker_id:"jdx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n14111:Worker {worker_id:"sze"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51305:Worker {worker_id:"xoi"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49854:Worker {worker_id:"ite"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49960:Worker {worker_id:"jsy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49989:Worker {worker_id:"kbc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50342:Worker {worker_id:"nnl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50644:Worker {worker_id:"qne"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50301:Worker {worker_id:"ndc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49556:Worker {worker_id:"fug"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51212:Worker {worker_id:"wov"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49149:Worker {worker_id:"bwv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49115:Worker {worker_id:"blj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50413:Worker {worker_id:"oeb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50603:Worker {worker_id:"qcu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49220:Worker {worker_id:"cmz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51193:Worker {worker_id:"wjd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50990:Worker {worker_id:"udm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49462:Worker {worker_id:"eyq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49344:Worker {worker_id:"dri"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51160:Worker {worker_id:"vzm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49835:Worker {worker_id:"ing"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50576:Worker {worker_id:"pxf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49485:Worker {worker_id:"fej"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49678:Worker {worker_id:"hce"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50920:Worker {worker_id:"tlr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51181:Worker {worker_id:"wga"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49515:Worker {worker_id:"flh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50012:Worker {worker_id:"kfx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50813:Worker {worker_id:"sjk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50759:Worker {worker_id:"rvt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49361:Worker {worker_id:"dtz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50175:Worker {worker_id:"lyb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49805:Worker {worker_id:"ifa"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49580:Worker {worker_id:"gbs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49584:Worker {worker_id:"gcs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49289:Worker {worker_id:"ddi"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50498:Worker {worker_id:"pcm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49826:Worker {worker_id:"ikz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51424:Worker {worker_id:"yru"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49517:Worker {worker_id:"fmc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50353:Worker {worker_id:"nps"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51331:Worker {worker_id:"xvw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51542:Worker {worker_id:"zzc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49376:Worker {worker_id:"dzl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48989:Worker {worker_id:"afk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51382:Worker {worker_id:"ygb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49701:Worker {worker_id:"hig"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49522:Worker {worker_id:"fnc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51258:Worker {worker_id:"xbg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49336:Worker {worker_id:"dpy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49817:Worker {worker_id:"ihy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50807:Worker {worker_id:"sid"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51330:Worker {worker_id:"xvr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50952:Worker {worker_id:"tsm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49208:Worker {worker_id:"cks"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50808:Worker {worker_id:"sij"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49047:Worker {worker_id:"atq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50216:Worker {worker_id:"mjh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49729:Worker {worker_id:"hov"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51455:Worker {worker_id:"yzj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50178:Worker {worker_id:"lyu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49619:Worker {worker_id:"gle"})
#
#    | a
# ---+-----------------------------------
#  1 | (n47386:Worker {worker_id:"odx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50410:Worker {worker_id:"oda"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50117:Worker {worker_id:"ljx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50873:Worker {worker_id:"szx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51093:Worker {worker_id:"vgc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50714:Worker {worker_id:"rlu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51300:Worker {worker_id:"xnt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50765:Worker {worker_id:"rxt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51240:Worker {worker_id:"wvz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50875:Worker {worker_id:"tai"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49045:Worker {worker_id:"arr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49006:Worker {worker_id:"ako"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50446:Worker {worker_id:"oop"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49962:Worker {worker_id:"jtc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50005:Worker {worker_id:"kdx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50510:Worker {worker_id:"pey"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49952:Worker {worker_id:"jqt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49968:Worker {worker_id:"jux"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51081:Worker {worker_id:"vch"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49821:Worker {worker_id:"ijf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50299:Worker {worker_id:"ncs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49780:Worker {worker_id:"ibd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49240:Worker {worker_id:"crq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51248:Worker {worker_id:"wxt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51188:Worker {worker_id:"whq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51535:Worker {worker_id:"zvt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48980:Worker {worker_id:"ads"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50758:Worker {worker_id:"rvs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51438:Worker {worker_id:"yux"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51155:Worker {worker_id:"vyt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49178:Worker {worker_id:"cdk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50383:Worker {worker_id:"nwd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50409:Worker {worker_id:"ocx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50471:Worker {worker_id:"ovd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49771:Worker {worker_id:"hzm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49295:Worker {worker_id:"del"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50965:Worker {worker_id:"tvm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50559:Worker {worker_id:"psx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50303:Worker {worker_id:"ndy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51320:Worker {worker_id:"xsc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51468:Worker {worker_id:"zeg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50254:Worker {worker_id:"msx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51122:Worker {worker_id:"vpy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50450:Worker {worker_id:"ope"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50653:Worker {worker_id:"qqv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50810:Worker {worker_id:"siy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49103:Worker {worker_id:"bjp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49111:Worker {worker_id:"bks"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50442:Worker {worker_id:"onw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50697:Worker {worker_id:"rgs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51156:Worker {worker_id:"vyu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51398:Worker {worker_id:"ylo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51282:Worker {worker_id:"xjj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50710:Worker {worker_id:"rkw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49239:Worker {worker_id:"crl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51517:Worker {worker_id:"zrh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48988:Worker {worker_id:"afj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49449:Worker {worker_id:"erm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49012:Worker {worker_id:"alq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50944:Worker {worker_id:"tqc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50146:Worker {worker_id:"lre"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49948:Worker {worker_id:"jpk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50447:Worker {worker_id:"oos"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49136:Worker {worker_id:"btj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49325:Worker {worker_id:"dmk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50583:Worker {worker_id:"pyo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49201:Worker {worker_id:"cjl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50997:Worker {worker_id:"ufx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50234:Worker {worker_id:"moe"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50707:Worker {worker_id:"rko"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51044:Worker {worker_id:"utm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51297:Worker {worker_id:"xnf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49546:Worker {worker_id:"fsd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51436:Worker {worker_id:"yuq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50264:Worker {worker_id:"muw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49763:Worker {worker_id:"hxf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50006:Worker {worker_id:"kdz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50647:Worker {worker_id:"qol"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49605:Worker {worker_id:"ghl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49429:Worker {worker_id:"ell"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49718:Worker {worker_id:"hmj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50533:Worker {worker_id:"pmn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51140:Worker {worker_id:"vul"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49924:Worker {worker_id:"jjt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51153:Worker {worker_id:"vyp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49782:Worker {worker_id:"ibj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50744:Worker {worker_id:"rtm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51450:Worker {worker_id:"yyk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50055:Worker {worker_id:"krg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50484:Worker {worker_id:"ozd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49251:Worker {worker_id:"cul"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51038:Worker {worker_id:"urx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49072:Worker {worker_id:"bcd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49293:Worker {worker_id:"dea"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49569:Worker {worker_id:"fxm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50795:Worker {worker_id:"sgt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50079:Worker {worker_id:"kxo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49752:Worker {worker_id:"hts"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49707:Worker {worker_id:"hju"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49971:Worker {worker_id:"jvh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49290:Worker {worker_id:"ddm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49566:Worker {worker_id:"fwv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51220:Worker {worker_id:"wqq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49287:Worker {worker_id:"dcg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51400:Worker {worker_id:"yly"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49598:Worker {worker_id:"gfw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51157:Worker {worker_id:"vzc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50319:Worker {worker_id:"nhd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49282:Worker {worker_id:"dal"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49775:Worker {worker_id:"iaa"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49837:Worker {worker_id:"inu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50267:Worker {worker_id:"mvc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49439:Worker {worker_id:"env"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51028:Worker {worker_id:"uov"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49046:Worker {worker_id:"ata"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49812:Worker {worker_id:"igq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50341:Worker {worker_id:"nmx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50059:Worker {worker_id:"ksh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49529:Worker {worker_id:"fpl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49674:Worker {worker_id:"hbp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50232:Worker {worker_id:"mmm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51111:Worker {worker_id:"vnb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49121:Worker {worker_id:"bnj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49311:Worker {worker_id:"dhp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51343:Worker {worker_id:"xyq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n14139:Worker {worker_id:"rqq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49879:Worker {worker_id:"iyt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49787:Worker {worker_id:"icd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50258:Worker {worker_id:"mtu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50182:Worker {worker_id:"lzj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49664:Worker {worker_id:"gzf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50602:Worker {worker_id:"qcp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49590:Worker {worker_id:"gek"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51410:Worker {worker_id:"yow"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51492:Worker {worker_id:"zkr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50272:Worker {worker_id:"mwu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50852:Worker {worker_id:"str"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49102:Worker {worker_id:"bjm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49131:Worker {worker_id:"brg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48999:Worker {worker_id:"aig"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48970:Worker {worker_id:"aaw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51101:Worker {worker_id:"vju"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49155:Worker {worker_id:"byb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49277:Worker {worker_id:"czn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49923:Worker {worker_id:"jjl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49818:Worker {worker_id:"iid"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48979:Worker {worker_id:"adi"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49400:Worker {worker_id:"eeq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50883:Worker {worker_id:"tbx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51446:Worker {worker_id:"ywt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50235:Worker {worker_id:"mol"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49463:Worker {worker_id:"eyt"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50401:Worker {worker_id:"obw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49579:Worker {worker_id:"gav"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49464:Worker {worker_id:"eyz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49381:Worker {worker_id:"eav"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49991:Worker {worker_id:"kbi"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49261:Worker {worker_id:"cvr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50500:Worker {worker_id:"pdc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50933:Worker {worker_id:"tnp"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50025:Worker {worker_id:"kiq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49458:Worker {worker_id:"exq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51379:Worker {worker_id:"yfl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49391:Worker {worker_id:"edb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50443:Worker {worker_id:"ony"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50959:Worker {worker_id:"tuf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49157:Worker {worker_id:"byn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50449:Worker {worker_id:"opb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49964:Worker {worker_id:"jtn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51334:Worker {worker_id:"xwx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50362:Worker {worker_id:"nss"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50204:Worker {worker_id:"mfw"})
#
#    | a
# ...
#  1 | (n50963:Worker {worker_id:"tvb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51433:Worker {worker_id:"yuh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50404:Worker {worker_id:"oca"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51510:Worker {worker_id:"zpw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49348:Worker {worker_id:"dsd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49437:Worker {worker_id:"emr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50129:Worker {worker_id:"lmn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49622:Worker {worker_id:"gnc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49777:Worker {worker_id:"iag"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50021:Worker {worker_id:"kic"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50477:Worker {worker_id:"owx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50227:Worker {worker_id:"mlg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50132:Worker {worker_id:"lna"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51413:Worker {worker_id:"ypv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50545:Worker {worker_id:"ppr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49947:Worker {worker_id:"jpg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49504:Worker {worker_id:"fig"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50460:Worker {worker_id:"osr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50791:Worker {worker_id:"see"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51163:Worker {worker_id:"wal"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49062:Worker {worker_id:"azn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49156:Worker {worker_id:"byi"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50153:Worker {worker_id:"lsl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50056:Worker {worker_id:"krq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50168:Worker {worker_id:"lvs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50463:Worker {worker_id:"otz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50784:Worker {worker_id:"sco"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51290:Worker {worker_id:"xks"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49669:Worker {worker_id:"haf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50866:Worker {worker_id:"sxx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50263:Worker {worker_id:"mut"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50664:Worker {worker_id:"qsx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49416:Worker {worker_id:"ejb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51031:Worker {worker_id:"ups"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49917:Worker {worker_id:"jif"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50508:Worker {worker_id:"pem"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49856:Worker {worker_id:"itl"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50988:Worker {worker_id:"udc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49474:Worker {worker_id:"fbq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49524:Worker {worker_id:"foo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50408:Worker {worker_id:"ocq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49519:Worker {worker_id:"fml"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49841:Worker {worker_id:"ipo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49769:Worker {worker_id:"hys"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51369:Worker {worker_id:"ydd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50001:Worker {worker_id:"kcu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50905:Worker {worker_id:"thd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50249:Worker {worker_id:"mrz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50811:Worker {worker_id:"sjg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49422:Worker {worker_id:"ejy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49602:Worker {worker_id:"ggx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50247:Worker {worker_id:"mrn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49135:Worker {worker_id:"bsk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49899:Worker {worker_id:"jdf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51507:Worker {worker_id:"zpm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50343:Worker {worker_id:"nnn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48975:Worker {worker_id:"abr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51180:Worker {worker_id:"wfj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49870:Worker {worker_id:"iwo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50302:Worker {worker_id:"ndo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49159:Worker {worker_id:"bzb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51241:Worker {worker_id:"wwb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49897:Worker {worker_id:"jcs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50118:Worker {worker_id:"lkc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50191:Worker {worker_id:"mcd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51368:Worker {worker_id:"ycx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50369:Worker {worker_id:"nud"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50520:Worker {worker_id:"pht"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50801:Worker {worker_id:"shh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50434:Worker {worker_id:"okn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50669:Worker {worker_id:"quy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50980:Worker {worker_id:"uap"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49611:Worker {worker_id:"gis"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49275:Worker {worker_id:"cye"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50111:Worker {worker_id:"lha"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51545:Worker {worker_id:"zzs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50882:Worker {worker_id:"tbv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49608:Worker {worker_id:"gid"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51428:Worker {worker_id:"ysm"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50805:Worker {worker_id:"shu"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51109:Worker {worker_id:"vme"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49231:Worker {worker_id:"coy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50727:Worker {worker_id:"rpb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50255:Worker {worker_id:"msy"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50256:Worker {worker_id:"mtb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49512:Worker {worker_id:"fky"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50848:Worker {worker_id:"ssc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49906:Worker {worker_id:"jex"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49356:Worker {worker_id:"dta"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50215:Worker {worker_id:"mje"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49042:Worker {worker_id:"aqs"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50563:Worker {worker_id:"ptn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50398:Worker {worker_id:"obr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49655:Worker {worker_id:"gvx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49183:Worker {worker_id:"cfb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50876:Worker {worker_id:"tao"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50701:Worker {worker_id:"rhw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49651:Worker {worker_id:"guh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51175:Worker {worker_id:"weq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50080:Worker {worker_id:"kxx"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49188:Worker {worker_id:"cgi"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49932:Worker {worker_id:"jlf"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50386:Worker {worker_id:"nxr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50888:Worker {worker_id:"tcz"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50384:Worker {worker_id:"nxb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49999:Worker {worker_id:"kcj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50553:Worker {worker_id:"pru"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49920:Worker {worker_id:"jin"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50762:Worker {worker_id:"rwn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51225:Worker {worker_id:"wsn"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50366:Worker {worker_id:"ntg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49696:Worker {worker_id:"hhj"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49618:Worker {worker_id:"gkr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49807:Worker {worker_id:"ifd"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49838:Worker {worker_id:"ioc"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49196:Worker {worker_id:"cik"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49194:Worker {worker_id:"cie"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50322:Worker {worker_id:"nip"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49179:Worker {worker_id:"cdv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49473:Worker {worker_id:"fbo"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49008:Worker {worker_id:"alb"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50760:Worker {worker_id:"rvv"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51408:Worker {worker_id:"yok"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50200:Worker {worker_id:"mff"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50060:Worker {worker_id:"ksk"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49052:Worker {worker_id:"awg"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49268:Worker {worker_id:"cxi"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49844:Worker {worker_id:"iqh"})
#
#    | a
# ---+-----------------------------------
#  1 | (n50593:Worker {worker_id:"qal"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51466:Worker {worker_id:"zde"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49427:Worker {worker_id:"eky"})
#
#    | a
# ---+-----------------------------------
#  1 | (n51161:Worker {worker_id:"vzr"})
#
#    | a
# ---+-----------------------------------
#  1 | (n48994:Worker {worker_id:"agw"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49022:Worker {worker_id:"anq"})
#
#    | a
# ---+-----------------------------------
#  1 | (n49187:Worker {worker_id:"cge"})

# %%
tx = graph.cypher.begin()
statement = ("MATCH (u:`Worker`{worker_id:{A}}) "
             "MATCH (m:`Worker`{worker_id:{C}}) MERGE (u)-[r:`Collaboration`]-(m) RETURN r")

# Looping over ratings
for r,row in W_df.iterrows() :
    # Retrieve "User" and "Movie" nodes, and create relationship with the corresponding rating as property
    tx.append(statement, {"A": row.loc['Worker1'],"C": row.loc['Worker2']})
    if r%100==0 : tx.process()

tx.commit()
# Out:
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"ksk"})-[r146488:Collaboration]->(:Worker {worker_id:"qal"})
#
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"awg"})-[r146489:Collaboration]->(:Worker {worker_id:"stb"})
#
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"cxi"})-[r146490:Collaboration]->(:Worker {worker_id:"vdz"})
#
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"iqh"})-[r146491:Collaboration]->(:Worker {worker_id:"urv"})
#
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"qal"})-[r146492:Collaboration]->(:Worker {worker_id:"nti"})
#
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zde"})-[r146493:Collaboration]->(:Worker {worker_id:"pxu"})
#
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"eky"})-[r146494:Collaboration]->(:Worker {worker_id:"ani"})
#
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"vzr"})-[r146495:Collaboration]->(:Worker {worker_id:"fsh"})
#
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"agw"})-[r146496:Collaboration]->(:Worker {worker_id:"ykq"})
#
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"anq"})-[r146497:Collaboration]->(:Worker {worker_id:"fvq"})
#
#    | r
# ---+----------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"cge"})-[r146498:Collaboration]->(:Worker {worker_id:"fsb"})

# %% [markdown]
# ### Cpher

# %% [markdown]
# find node 'xev'
# MATCH p= (n:Worker)-[r:Contribution]->(m:Repo) where n.worker_id='xev' return p

# %% [markdown]
# clear
# MATCH (n:Worker)-[r:Collaboration]-(m:Worker) detach DELETE n,r,m

# %% [markdown]
# ## B. Developer - Project

# %%
##### Create the nodes relative to workers, each one being identified by its user_id #####
# "MERGE" request : creates a new node if it does not exist already
tx = graph.cypher.begin()
statement = "MERGE (a:`Worker`{worker_id:{A}}) RETURN a"
for u in df_collaborative['Worker ID'].unique():
    tx.append(statement, {"A": u})

tx.commit()


##### Create the nodes relative to Genres, each one being identified by its genre_id, and with the property name #####
tx = graph.cypher.begin()
statement = "MERGE (a:`Repo`{repo_id:{A}}) RETURN a"
for g in df_collaborative['Repository ID'].unique() :
    tx.append(statement, {"A": g})

tx.commit()
# Out:
#    | a
# ---+-------------------------------
#  1 | (n51547:Repo {repo_id:"AAA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51548:Repo {repo_id:"KNU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51549:Repo {repo_id:"NLY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51550:Repo {repo_id:"LZH"})
#
#    | a
# ---+-------------------------------
#  1 | (n51551:Repo {repo_id:"QGX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51552:Repo {repo_id:"DOL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51553:Repo {repo_id:"DXH"})
#
#    | a
# ---+-------------------------------
#  1 | (n51554:Repo {repo_id:"EFF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51555:Repo {repo_id:"EVF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51556:Repo {repo_id:"GQY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51557:Repo {repo_id:"GTX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51558:Repo {repo_id:"GWU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51559:Repo {repo_id:"HAT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51560:Repo {repo_id:"IEA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51561:Repo {repo_id:"KOB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51562:Repo {repo_id:"LPU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51563:Repo {repo_id:"LYV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51564:Repo {repo_id:"MUT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51565:Repo {repo_id:"NIH"})
#
#    | a
# ---+-------------------------------
#  1 | (n51566:Repo {repo_id:"OOL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51567:Repo {repo_id:"RIT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51568:Repo {repo_id:"TJK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51569:Repo {repo_id:"UYG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51570:Repo {repo_id:"VNN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51571:Repo {repo_id:"WFL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51572:Repo {repo_id:"XUY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51573:Repo {repo_id:"ZOI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51574:Repo {repo_id:"MWP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51575:Repo {repo_id:"FTK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51576:Repo {repo_id:"FYL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51577:Repo {repo_id:"PHM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51578:Repo {repo_id:"KGD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51579:Repo {repo_id:"QXO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51580:Repo {repo_id:"WQP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51581:Repo {repo_id:"GYI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51582:Repo {repo_id:"QLR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51583:Repo {repo_id:"SKK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51584:Repo {repo_id:"WTN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51585:Repo {repo_id:"TEK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51586:Repo {repo_id:"XHS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51587:Repo {repo_id:"JNW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51588:Repo {repo_id:"MCW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51589:Repo {repo_id:"EIY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51590:Repo {repo_id:"EPX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51591:Repo {repo_id:"GCG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51592:Repo {repo_id:"HDZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51593:Repo {repo_id:"KPH"})
#
#    | a
# ---+-------------------------------
#  1 | (n51594:Repo {repo_id:"OGE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51595:Repo {repo_id:"QOS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51596:Repo {repo_id:"XZE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51597:Repo {repo_id:"COH"})
#
#    | a
# ---+-------------------------------
#  1 | (n51598:Repo {repo_id:"OIU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51599:Repo {repo_id:"MRX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51600:Repo {repo_id:"EKN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51601:Repo {repo_id:"ICP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51602:Repo {repo_id:"IKS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51603:Repo {repo_id:"QRB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51604:Repo {repo_id:"QVY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51605:Repo {repo_id:"RSV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51606:Repo {repo_id:"DCM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51607:Repo {repo_id:"MEY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51608:Repo {repo_id:"HEL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51609:Repo {repo_id:"TCS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51610:Repo {repo_id:"GLC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51611:Repo {repo_id:"GMW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51612:Repo {repo_id:"OGO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51613:Repo {repo_id:"ECK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51614:Repo {repo_id:"KAM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51615:Repo {repo_id:"MNG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51616:Repo {repo_id:"AGH"})
#
#    | a
# ---+-------------------------------
#  1 | (n51617:Repo {repo_id:"BBG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51618:Repo {repo_id:"WFP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51619:Repo {repo_id:"EWC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51620:Repo {repo_id:"FGU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51621:Repo {repo_id:"KYT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51622:Repo {repo_id:"LMO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51623:Repo {repo_id:"MKX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51624:Repo {repo_id:"STC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51625:Repo {repo_id:"TOI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51626:Repo {repo_id:"UBG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51627:Repo {repo_id:"VAQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51628:Repo {repo_id:"FKJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51629:Repo {repo_id:"HJT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51630:Repo {repo_id:"YMI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51631:Repo {repo_id:"HFQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51632:Repo {repo_id:"OOT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51633:Repo {repo_id:"AWU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51634:Repo {repo_id:"LHC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51635:Repo {repo_id:"RRC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51636:Repo {repo_id:"LSY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51637:Repo {repo_id:"YAM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51638:Repo {repo_id:"JXW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51639:Repo {repo_id:"OCG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51640:Repo {repo_id:"OFX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51641:Repo {repo_id:"RLM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51642:Repo {repo_id:"HDR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51643:Repo {repo_id:"HWK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51644:Repo {repo_id:"GJW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51645:Repo {repo_id:"JHQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51646:Repo {repo_id:"QAT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51647:Repo {repo_id:"QRS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51648:Repo {repo_id:"ASY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51649:Repo {repo_id:"YTJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51650:Repo {repo_id:"VKA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51651:Repo {repo_id:"RDN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51652:Repo {repo_id:"VTP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51653:Repo {repo_id:"KXS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51654:Repo {repo_id:"ZSI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51655:Repo {repo_id:"MYN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51656:Repo {repo_id:"KRL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51657:Repo {repo_id:"XBV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51658:Repo {repo_id:"THG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51659:Repo {repo_id:"CUE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51660:Repo {repo_id:"GYL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51661:Repo {repo_id:"ZOD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51662:Repo {repo_id:"SME"})
#
#    | a
# ---+-------------------------------
#  1 | (n51663:Repo {repo_id:"UKF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51664:Repo {repo_id:"BIM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51665:Repo {repo_id:"EES"})
#
#    | a
# ---+-------------------------------
#  1 | (n51666:Repo {repo_id:"IRN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51667:Repo {repo_id:"QWB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51668:Repo {repo_id:"NOG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51669:Repo {repo_id:"VGS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51670:Repo {repo_id:"ATX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51671:Repo {repo_id:"BLR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51672:Repo {repo_id:"BMA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51673:Repo {repo_id:"DNE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51674:Repo {repo_id:"DOI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51675:Repo {repo_id:"DUP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51676:Repo {repo_id:"FKF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51677:Repo {repo_id:"FOW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51678:Repo {repo_id:"GHX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51679:Repo {repo_id:"HGX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51680:Repo {repo_id:"HTV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51681:Repo {repo_id:"LET"})
#
#    | a
# ---+-------------------------------
#  1 | (n51682:Repo {repo_id:"UDG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51683:Repo {repo_id:"WSY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51684:Repo {repo_id:"ZSA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51685:Repo {repo_id:"EQA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51686:Repo {repo_id:"FAB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51687:Repo {repo_id:"PLS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51688:Repo {repo_id:"VRS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51689:Repo {repo_id:"SPG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51690:Repo {repo_id:"XDJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51691:Repo {repo_id:"CRD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51692:Repo {repo_id:"SAA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51693:Repo {repo_id:"AVN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51694:Repo {repo_id:"CSA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51695:Repo {repo_id:"JHL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51696:Repo {repo_id:"KMP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51697:Repo {repo_id:"MWT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51698:Repo {repo_id:"QQS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51699:Repo {repo_id:"SKG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51700:Repo {repo_id:"GRN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51701:Repo {repo_id:"WZI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51702:Repo {repo_id:"BLK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51703:Repo {repo_id:"DTU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51704:Repo {repo_id:"EBW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51705:Repo {repo_id:"TOE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51706:Repo {repo_id:"TQG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51707:Repo {repo_id:"TUU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51708:Repo {repo_id:"EEX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51709:Repo {repo_id:"NEL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51710:Repo {repo_id:"SDV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51711:Repo {repo_id:"STO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51712:Repo {repo_id:"JSQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51713:Repo {repo_id:"PVZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51714:Repo {repo_id:"WUD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51715:Repo {repo_id:"BEK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51716:Repo {repo_id:"RLJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51717:Repo {repo_id:"GXO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51718:Repo {repo_id:"GXU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51719:Repo {repo_id:"GYY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51720:Repo {repo_id:"INY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51721:Repo {repo_id:"JDN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51722:Repo {repo_id:"RUX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51723:Repo {repo_id:"MZA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51724:Repo {repo_id:"OBV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51725:Repo {repo_id:"OQJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51726:Repo {repo_id:"BNE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51727:Repo {repo_id:"DKJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51728:Repo {repo_id:"HOU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51729:Repo {repo_id:"OPO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51730:Repo {repo_id:"XXM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51731:Repo {repo_id:"UYI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51732:Repo {repo_id:"XFB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51733:Repo {repo_id:"PRP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51734:Repo {repo_id:"YMJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51735:Repo {repo_id:"HIS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51736:Repo {repo_id:"MNT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51737:Repo {repo_id:"QRO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51738:Repo {repo_id:"VXO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51739:Repo {repo_id:"NWN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51740:Repo {repo_id:"VJD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51741:Repo {repo_id:"CNJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51742:Repo {repo_id:"HJO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51743:Repo {repo_id:"HZO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51744:Repo {repo_id:"XQB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51745:Repo {repo_id:"EGO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51746:Repo {repo_id:"NKC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51747:Repo {repo_id:"DQY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51748:Repo {repo_id:"EUQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51749:Repo {repo_id:"YYI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51750:Repo {repo_id:"GSE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51751:Repo {repo_id:"FQV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51752:Repo {repo_id:"YEV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51753:Repo {repo_id:"DGS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51754:Repo {repo_id:"ZVN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51755:Repo {repo_id:"LRF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51756:Repo {repo_id:"XWQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51757:Repo {repo_id:"GXB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51758:Repo {repo_id:"QZO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51759:Repo {repo_id:"UPT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51760:Repo {repo_id:"RSO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51761:Repo {repo_id:"VME"})
#
#    | a
# ---+-------------------------------
#  1 | (n51762:Repo {repo_id:"APY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51763:Repo {repo_id:"JBF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51764:Repo {repo_id:"BKU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51765:Repo {repo_id:"IWY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51766:Repo {repo_id:"MHY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51767:Repo {repo_id:"WMS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51768:Repo {repo_id:"YHM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51769:Repo {repo_id:"BJG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51770:Repo {repo_id:"BKW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51771:Repo {repo_id:"JJP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51772:Repo {repo_id:"NHF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51773:Repo {repo_id:"PUX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51774:Repo {repo_id:"LJR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51775:Repo {repo_id:"VXK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51776:Repo {repo_id:"WSO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51777:Repo {repo_id:"XYJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51778:Repo {repo_id:"EBB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51779:Repo {repo_id:"BEL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51780:Repo {repo_id:"NJQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51781:Repo {repo_id:"GEV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51782:Repo {repo_id:"JYX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51783:Repo {repo_id:"NBX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51784:Repo {repo_id:"OQA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51785:Repo {repo_id:"ALN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51786:Repo {repo_id:"NDJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51787:Repo {repo_id:"DZF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51788:Repo {repo_id:"FBM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51789:Repo {repo_id:"GYM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51790:Repo {repo_id:"HVO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51791:Repo {repo_id:"OGF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51792:Repo {repo_id:"OXA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51793:Repo {repo_id:"WPT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51794:Repo {repo_id:"ZZO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51795:Repo {repo_id:"HSS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51796:Repo {repo_id:"VBP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51797:Repo {repo_id:"FBN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51798:Repo {repo_id:"FLP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51799:Repo {repo_id:"MQF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51800:Repo {repo_id:"QQX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51801:Repo {repo_id:"ZIG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51802:Repo {repo_id:"IXF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51803:Repo {repo_id:"VBZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51804:Repo {repo_id:"CLC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51805:Repo {repo_id:"MYL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51806:Repo {repo_id:"CKZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51807:Repo {repo_id:"EST"})
#
#    | a
# ---+-------------------------------
#  1 | (n51808:Repo {repo_id:"EXO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51809:Repo {repo_id:"GCQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51810:Repo {repo_id:"GJE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51811:Repo {repo_id:"HIF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51812:Repo {repo_id:"ISR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51813:Repo {repo_id:"IWR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51814:Repo {repo_id:"KUH"})
#
#    | a
# ---+-------------------------------
#  1 | (n51815:Repo {repo_id:"LTA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51816:Repo {repo_id:"MOZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51817:Repo {repo_id:"NSO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51818:Repo {repo_id:"OGA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51819:Repo {repo_id:"OJA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51820:Repo {repo_id:"OUR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51821:Repo {repo_id:"SGT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51822:Repo {repo_id:"UTD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51823:Repo {repo_id:"VKN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51824:Repo {repo_id:"KHL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51825:Repo {repo_id:"KGO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51826:Repo {repo_id:"PTK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51827:Repo {repo_id:"UAD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51828:Repo {repo_id:"APK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51829:Repo {repo_id:"IHA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51830:Repo {repo_id:"PKG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51831:Repo {repo_id:"SMD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51832:Repo {repo_id:"VUM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51833:Repo {repo_id:"FOO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51834:Repo {repo_id:"ZVR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51835:Repo {repo_id:"OJG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51836:Repo {repo_id:"HOE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51837:Repo {repo_id:"YWN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51838:Repo {repo_id:"GUZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51839:Repo {repo_id:"JWO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51840:Repo {repo_id:"DKD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51841:Repo {repo_id:"LSL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51842:Repo {repo_id:"PGC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51843:Repo {repo_id:"VKG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51844:Repo {repo_id:"ZTD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51845:Repo {repo_id:"SDX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51846:Repo {repo_id:"VYF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51847:Repo {repo_id:"ATT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51848:Repo {repo_id:"IFW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51849:Repo {repo_id:"VPP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51850:Repo {repo_id:"YKZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51851:Repo {repo_id:"BGH"})
#
#    | a
# ---+-------------------------------
#  1 | (n51852:Repo {repo_id:"HZS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51853:Repo {repo_id:"SFT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51854:Repo {repo_id:"YZT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51855:Repo {repo_id:"ZRC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51856:Repo {repo_id:"NBJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51857:Repo {repo_id:"JNA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51858:Repo {repo_id:"XJW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51859:Repo {repo_id:"VPS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51860:Repo {repo_id:"XRO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51861:Repo {repo_id:"ZDB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51862:Repo {repo_id:"ZHI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51863:Repo {repo_id:"CQO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51864:Repo {repo_id:"FNZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51865:Repo {repo_id:"HJR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51866:Repo {repo_id:"IHV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51867:Repo {repo_id:"YNE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51868:Repo {repo_id:"JID"})
#
#    | a
# ---+-------------------------------
#  1 | (n51869:Repo {repo_id:"ZFM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51870:Repo {repo_id:"BSO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51871:Repo {repo_id:"YZO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51872:Repo {repo_id:"KSD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51873:Repo {repo_id:"VMI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51874:Repo {repo_id:"WDC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51875:Repo {repo_id:"AOZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51876:Repo {repo_id:"PRR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51877:Repo {repo_id:"QTK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51878:Repo {repo_id:"LSO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51879:Repo {repo_id:"JUO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51880:Repo {repo_id:"CZI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51881:Repo {repo_id:"REA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51882:Repo {repo_id:"RXS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51883:Repo {repo_id:"UDZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51884:Repo {repo_id:"XKI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51885:Repo {repo_id:"YGF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51886:Repo {repo_id:"SHR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51887:Repo {repo_id:"KFV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51888:Repo {repo_id:"PDE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51889:Repo {repo_id:"WDW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51890:Repo {repo_id:"IGJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51891:Repo {repo_id:"RNR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51892:Repo {repo_id:"VDS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51893:Repo {repo_id:"EGC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51894:Repo {repo_id:"FKC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51895:Repo {repo_id:"KKJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51896:Repo {repo_id:"LLF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51897:Repo {repo_id:"LPC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51898:Repo {repo_id:"MAL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51899:Repo {repo_id:"MWN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51900:Repo {repo_id:"NAA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51901:Repo {repo_id:"NQN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51902:Repo {repo_id:"OXE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51903:Repo {repo_id:"TDX"})
#
#    | a
# ---+-------------------------------
#  1 | (n51904:Repo {repo_id:"URO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51905:Repo {repo_id:"WLS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51906:Repo {repo_id:"WRO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51907:Repo {repo_id:"LOA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51908:Repo {repo_id:"MRR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51909:Repo {repo_id:"GJO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51910:Repo {repo_id:"HEJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51911:Repo {repo_id:"LNZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51912:Repo {repo_id:"MOQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51913:Repo {repo_id:"PWO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51914:Repo {repo_id:"SLP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51915:Repo {repo_id:"THC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51916:Repo {repo_id:"UXL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51917:Repo {repo_id:"XEZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51918:Repo {repo_id:"QEP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51919:Repo {repo_id:"TSZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51920:Repo {repo_id:"JIV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51921:Repo {repo_id:"ARN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51922:Repo {repo_id:"BAJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51923:Repo {repo_id:"KLJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51924:Repo {repo_id:"PXD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51925:Repo {repo_id:"RGO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51926:Repo {repo_id:"SLK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51927:Repo {repo_id:"TWW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51928:Repo {repo_id:"ICW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51929:Repo {repo_id:"KUF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51930:Repo {repo_id:"ORR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51931:Repo {repo_id:"QGD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51932:Repo {repo_id:"VHN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51933:Repo {repo_id:"WDU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51934:Repo {repo_id:"WFZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51935:Repo {repo_id:"ZSE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51936:Repo {repo_id:"FPK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51937:Repo {repo_id:"MJP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51938:Repo {repo_id:"RYK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51939:Repo {repo_id:"WGV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51940:Repo {repo_id:"FVA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51941:Repo {repo_id:"WQD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51942:Repo {repo_id:"OBZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51943:Repo {repo_id:"EFN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51944:Repo {repo_id:"HCT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51945:Repo {repo_id:"ICT"})
#
#    | a
# ---+-------------------------------
#  1 | (n51946:Repo {repo_id:"MBV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51947:Repo {repo_id:"XLK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51948:Repo {repo_id:"HJD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51949:Repo {repo_id:"DLG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51950:Repo {repo_id:"OIP"})
#
#    | a
# ---+-------------------------------
#  1 | (n51951:Repo {repo_id:"DQZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51952:Repo {repo_id:"JTV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51953:Repo {repo_id:"DCN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51954:Repo {repo_id:"JCD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51955:Repo {repo_id:"HBL"})
#
#    | a
# ---+-------------------------------
#  1 | (n51956:Repo {repo_id:"DGV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51957:Repo {repo_id:"SIB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51958:Repo {repo_id:"ETJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51959:Repo {repo_id:"FOS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51960:Repo {repo_id:"JTA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51961:Repo {repo_id:"UKA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51962:Repo {repo_id:"EZU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51963:Repo {repo_id:"CIN"})
#
#    | a
# ---+-------------------------------
#  1 | (n51964:Repo {repo_id:"XAI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51965:Repo {repo_id:"QEM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51966:Repo {repo_id:"AHG"})
#
#    | a
# ---+-------------------------------
#  1 | (n51967:Repo {repo_id:"EDB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51968:Repo {repo_id:"PBJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n51969:Repo {repo_id:"ROR"})
#
#    | a
# ---+-------------------------------
#  1 | (n51970:Repo {repo_id:"RPO"})
#
#    | a
# ---+-------------------------------
#  1 | (n51971:Repo {repo_id:"TET"})
#
#    | a
# ---+-------------------------------
#  1 | (n51972:Repo {repo_id:"UDY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51973:Repo {repo_id:"YNS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51974:Repo {repo_id:"ZPI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51975:Repo {repo_id:"DLB"})
#
#    | a
# ---+-------------------------------
#  1 | (n51976:Repo {repo_id:"FXV"})
#
#    | a
# ---+-------------------------------
#  1 | (n51977:Repo {repo_id:"LCM"})
#
#    | a
# ---+-------------------------------
#  1 | (n51978:Repo {repo_id:"LTW"})
#
#    | a
# ---+-------------------------------
#  1 | (n51979:Repo {repo_id:"PKU"})
#
#    | a
# ---+-------------------------------
#  1 | (n51980:Repo {repo_id:"QOH"})
#
#    | a
# ---+-------------------------------
#  1 | (n51981:Repo {repo_id:"SPY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51982:Repo {repo_id:"UEE"})
#
#    | a
# ---+-------------------------------
#  1 | (n51983:Repo {repo_id:"VNK"})
#
#    | a
# ---+-------------------------------
#  1 | (n51984:Repo {repo_id:"CUI"})
#
#    | a
# ---+-------------------------------
#  1 | (n51985:Repo {repo_id:"AES"})
#
#    | a
# ---+-------------------------------
#  1 | (n51986:Repo {repo_id:"AVD"})
#
#    | a
# ---+-------------------------------
#  1 | (n51987:Repo {repo_id:"HMF"})
#
#    | a
# ---+-------------------------------
#  1 | (n51988:Repo {repo_id:"PCS"})
#
#    | a
# ---+-------------------------------
#  1 | (n51989:Repo {repo_id:"AFC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51990:Repo {repo_id:"CBA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51991:Repo {repo_id:"DVC"})
#
#    | a
# ---+-------------------------------
#  1 | (n51992:Repo {repo_id:"FGY"})
#
#    | a
# ---+-------------------------------
#  1 | (n51993:Repo {repo_id:"HSA"})
#
#    | a
# ---+-------------------------------
#  1 | (n51994:Repo {repo_id:"ITO"})
#
#    | a
# ...
#  1 | (n53102:Repo {repo_id:"NSB"})
#
#    | a
# ---+-------------------------------
#  1 | (n53103:Repo {repo_id:"VBG"})
#
#    | a
# ---+-------------------------------
#  1 | (n53104:Repo {repo_id:"TRC"})
#
#    | a
# ---+-------------------------------
#  1 | (n53105:Repo {repo_id:"VJN"})
#
#    | a
# ---+-------------------------------
#  1 | (n53106:Repo {repo_id:"ZJF"})
#
#    | a
# ---+-------------------------------
#  1 | (n53107:Repo {repo_id:"XYA"})
#
#    | a
# ---+-------------------------------
#  1 | (n53108:Repo {repo_id:"IPO"})
#
#    | a
# ---+-------------------------------
#  1 | (n53109:Repo {repo_id:"PWE"})
#
#    | a
# ---+-------------------------------
#  1 | (n53110:Repo {repo_id:"NQY"})
#
#    | a
# ---+-------------------------------
#  1 | (n53111:Repo {repo_id:"AIQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53112:Repo {repo_id:"CHP"})
#
#    | a
# ---+-------------------------------
#  1 | (n53113:Repo {repo_id:"PRW"})
#
#    | a
# ---+-------------------------------
#  1 | (n53114:Repo {repo_id:"BTY"})
#
#    | a
# ---+-------------------------------
#  1 | (n53115:Repo {repo_id:"QPP"})
#
#    | a
# ---+-------------------------------
#  1 | (n53116:Repo {repo_id:"KSU"})
#
#    | a
# ---+-------------------------------
#  1 | (n53117:Repo {repo_id:"WAB"})
#
#    | a
# ---+-------------------------------
#  1 | (n53118:Repo {repo_id:"OEE"})
#
#    | a
# ---+-------------------------------
#  1 | (n53119:Repo {repo_id:"KHE"})
#
#    | a
# ---+-------------------------------
#  1 | (n53120:Repo {repo_id:"HUB"})
#
#    | a
# ---+-------------------------------
#  1 | (n53121:Repo {repo_id:"RJA"})
#
#    | a
# ---+-------------------------------
#  1 | (n53122:Repo {repo_id:"ASP"})
#
#    | a
# ---+-------------------------------
#  1 | (n53123:Repo {repo_id:"QSD"})
#
#    | a
# ---+-------------------------------
#  1 | (n53124:Repo {repo_id:"GON"})
#
#    | a
# ---+-------------------------------
#  1 | (n53125:Repo {repo_id:"SDY"})
#
#    | a
# ---+-------------------------------
#  1 | (n53126:Repo {repo_id:"FVQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53127:Repo {repo_id:"HXJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53128:Repo {repo_id:"JNQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53129:Repo {repo_id:"SNX"})
#
#    | a
# ---+-------------------------------
#  1 | (n53130:Repo {repo_id:"IXB"})
#
#    | a
# ---+-------------------------------
#  1 | (n53131:Repo {repo_id:"KPJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53132:Repo {repo_id:"NGQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53133:Repo {repo_id:"RYL"})
#
#    | a
# ---+-------------------------------
#  1 | (n53134:Repo {repo_id:"SBZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53135:Repo {repo_id:"SVT"})
#
#    | a
# ---+-------------------------------
#  1 | (n53136:Repo {repo_id:"XDC"})
#
#    | a
# ---+-------------------------------
#  1 | (n53137:Repo {repo_id:"YVI"})
#
#    | a
# ---+-------------------------------
#  1 | (n53138:Repo {repo_id:"YWD"})
#
#    | a
# ---+-------------------------------
#  1 | (n53139:Repo {repo_id:"YWT"})
#
#    | a
# ---+-------------------------------
#  1 | (n53140:Repo {repo_id:"XUL"})
#
#    | a
# ---+-------------------------------
#  1 | (n53141:Repo {repo_id:"AGY"})
#
#    | a
# ---+-------------------------------
#  1 | (n53142:Repo {repo_id:"AXF"})
#
#    | a
# ---+-------------------------------
#  1 | (n53143:Repo {repo_id:"QNY"})
#
#    | a
# ---+-------------------------------
#  1 | (n53144:Repo {repo_id:"VDE"})
#
#    | a
# ---+-------------------------------
#  1 | (n53145:Repo {repo_id:"OBQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53146:Repo {repo_id:"UVE"})
#
#    | a
# ---+-------------------------------
#  1 | (n53147:Repo {repo_id:"ANF"})
#
#    | a
# ---+-------------------------------
#  1 | (n53148:Repo {repo_id:"BUO"})
#
#    | a
# ---+-------------------------------
#  1 | (n53149:Repo {repo_id:"DCK"})
#
#    | a
# ---+-------------------------------
#  1 | (n53150:Repo {repo_id:"FII"})
#
#    | a
# ---+-------------------------------
#  1 | (n53151:Repo {repo_id:"GKH"})
#
#    | a
# ---+-------------------------------
#  1 | (n53152:Repo {repo_id:"JRF"})
#
#    | a
# ---+-------------------------------
#  1 | (n53153:Repo {repo_id:"KWM"})
#
#    | a
# ---+-------------------------------
#  1 | (n53154:Repo {repo_id:"QZB"})
#
#    | a
# ---+-------------------------------
#  1 | (n53155:Repo {repo_id:"RFJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53156:Repo {repo_id:"WSK"})
#
#    | a
# ---+-------------------------------
#  1 | (n53157:Repo {repo_id:"ZCA"})
#
#    | a
# ---+-------------------------------
#  1 | (n53158:Repo {repo_id:"RES"})
#
#    | a
# ---+-------------------------------
#  1 | (n53159:Repo {repo_id:"IFC"})
#
#    | a
# ---+-------------------------------
#  1 | (n53160:Repo {repo_id:"BBD"})
#
#    | a
# ---+-------------------------------
#  1 | (n53161:Repo {repo_id:"FGZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53162:Repo {repo_id:"LFH"})
#
#    | a
# ---+-------------------------------
#  1 | (n53163:Repo {repo_id:"NSM"})
#
#    | a
# ---+-------------------------------
#  1 | (n53164:Repo {repo_id:"OIR"})
#
#    | a
# ---+-------------------------------
#  1 | (n53165:Repo {repo_id:"OZE"})
#
#    | a
# ---+-------------------------------
#  1 | (n53166:Repo {repo_id:"QFS"})
#
#    | a
# ---+-------------------------------
#  1 | (n53167:Repo {repo_id:"SMK"})
#
#    | a
# ---+-------------------------------
#  1 | (n53168:Repo {repo_id:"TAD"})
#
#    | a
# ---+-------------------------------
#  1 | (n53169:Repo {repo_id:"TEW"})
#
#    | a
# ---+-------------------------------
#  1 | (n53170:Repo {repo_id:"UOB"})
#
#    | a
# ---+-------------------------------
#  1 | (n53171:Repo {repo_id:"UPZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53172:Repo {repo_id:"WBD"})
#
#    | a
# ---+-------------------------------
#  1 | (n53173:Repo {repo_id:"RDD"})
#
#    | a
# ---+-------------------------------
#  1 | (n53174:Repo {repo_id:"EUT"})
#
#    | a
# ---+-------------------------------
#  1 | (n53175:Repo {repo_id:"JZC"})
#
#    | a
# ---+-------------------------------
#  1 | (n53176:Repo {repo_id:"KLW"})
#
#    | a
# ---+-------------------------------
#  1 | (n53177:Repo {repo_id:"ACW"})
#
#    | a
# ---+-------------------------------
#  1 | (n53178:Repo {repo_id:"AKI"})
#
#    | a
# ---+-------------------------------
#  1 | (n53179:Repo {repo_id:"AWB"})
#
#    | a
# ---+-------------------------------
#  1 | (n53180:Repo {repo_id:"BHM"})
#
#    | a
# ---+-------------------------------
#  1 | (n53181:Repo {repo_id:"BJZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53182:Repo {repo_id:"DII"})
#
#    | a
# ---+-------------------------------
#  1 | (n53183:Repo {repo_id:"HJJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53184:Repo {repo_id:"HSQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53185:Repo {repo_id:"IIV"})
#
#    | a
# ---+-------------------------------
#  1 | (n53186:Repo {repo_id:"IQU"})
#
#    | a
# ---+-------------------------------
#  1 | (n53187:Repo {repo_id:"LES"})
#
#    | a
# ---+-------------------------------
#  1 | (n53188:Repo {repo_id:"QVK"})
#
#    | a
# ---+-------------------------------
#  1 | (n53189:Repo {repo_id:"RDR"})
#
#    | a
# ---+-------------------------------
#  1 | (n53190:Repo {repo_id:"TFJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53191:Repo {repo_id:"WQI"})
#
#    | a
# ---+-------------------------------
#  1 | (n53192:Repo {repo_id:"YSO"})
#
#    | a
# ---+-------------------------------
#  1 | (n53193:Repo {repo_id:"NKU"})
#
#    | a
# ---+-------------------------------
#  1 | (n53194:Repo {repo_id:"TBN"})
#
#    | a
# ---+-------------------------------
#  1 | (n53195:Repo {repo_id:"UPU"})
#
#    | a
# ---+-------------------------------
#  1 | (n53196:Repo {repo_id:"VAE"})
#
#    | a
# ---+-------------------------------
#  1 | (n53197:Repo {repo_id:"VFE"})
#
#    | a
# ---+-------------------------------
#  1 | (n53198:Repo {repo_id:"IFQ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53199:Repo {repo_id:"ILC"})
#
#    | a
# ---+-------------------------------
#  1 | (n53200:Repo {repo_id:"GJN"})
#
#    | a
# ---+-------------------------------
#  1 | (n53201:Repo {repo_id:"RSF"})
#
#    | a
# ---+-------------------------------
#  1 | (n53202:Repo {repo_id:"YLU"})
#
#    | a
# ---+-------------------------------
#  1 | (n53203:Repo {repo_id:"CRR"})
#
#    | a
# ---+-------------------------------
#  1 | (n53204:Repo {repo_id:"HDX"})
#
#    | a
# ---+-------------------------------
#  1 | (n53205:Repo {repo_id:"XTT"})
#
#    | a
# ---+-------------------------------
#  1 | (n53206:Repo {repo_id:"EBL"})
#
#    | a
# ---+-------------------------------
#  1 | (n53207:Repo {repo_id:"ZUX"})
#
#    | a
# ---+-------------------------------
#  1 | (n53208:Repo {repo_id:"BHJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53209:Repo {repo_id:"UBE"})
#
#    | a
# ---+-------------------------------
#  1 | (n53210:Repo {repo_id:"ANC"})
#
#    | a
# ---+-------------------------------
#  1 | (n53211:Repo {repo_id:"FFZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53212:Repo {repo_id:"KEK"})
#
#    | a
# ---+-------------------------------
#  1 | (n53213:Repo {repo_id:"XEI"})
#
#    | a
# ---+-------------------------------
#  1 | (n53214:Repo {repo_id:"FMI"})
#
#    | a
# ---+-------------------------------
#  1 | (n53215:Repo {repo_id:"HZY"})
#
#    | a
# ---+-------------------------------
#  1 | (n53216:Repo {repo_id:"NDR"})
#
#    | a
# ---+-------------------------------
#  1 | (n53217:Repo {repo_id:"YOS"})
#
#    | a
# ---+-------------------------------
#  1 | (n53218:Repo {repo_id:"BUC"})
#
#    | a
# ---+-------------------------------
#  1 | (n53219:Repo {repo_id:"YKT"})
#
#    | a
# ---+-------------------------------
#  1 | (n53220:Repo {repo_id:"NFO"})
#
#    | a
# ---+-------------------------------
#  1 | (n53221:Repo {repo_id:"JOJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53222:Repo {repo_id:"ZEL"})
#
#    | a
# ---+-------------------------------
#  1 | (n53223:Repo {repo_id:"BBU"})
#
#    | a
# ---+-------------------------------
#  1 | (n53224:Repo {repo_id:"KKU"})
#
#    | a
# ---+-------------------------------
#  1 | (n53225:Repo {repo_id:"LWS"})
#
#    | a
# ---+-------------------------------
#  1 | (n53226:Repo {repo_id:"NJR"})
#
#    | a
# ---+-------------------------------
#  1 | (n53227:Repo {repo_id:"OGW"})
#
#    | a
# ---+-------------------------------
#  1 | (n53228:Repo {repo_id:"PGD"})
#
#    | a
# ---+-------------------------------
#  1 | (n53229:Repo {repo_id:"PLD"})
#
#    | a
# ---+-------------------------------
#  1 | (n53230:Repo {repo_id:"QBC"})
#
#    | a
# ---+-------------------------------
#  1 | (n53231:Repo {repo_id:"QBR"})
#
#    | a
# ---+-------------------------------
#  1 | (n53232:Repo {repo_id:"QCX"})
#
#    | a
# ---+-------------------------------
#  1 | (n53233:Repo {repo_id:"WGZ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53234:Repo {repo_id:"WYH"})
#
#    | a
# ---+-------------------------------
#  1 | (n53235:Repo {repo_id:"SAR"})
#
#    | a
# ---+-------------------------------
#  1 | (n53236:Repo {repo_id:"SVY"})
#
#    | a
# ---+-------------------------------
#  1 | (n53237:Repo {repo_id:"VYP"})
#
#    | a
# ---+-------------------------------
#  1 | (n53238:Repo {repo_id:"WSR"})
#
#    | a
# ---+-------------------------------
#  1 | (n53239:Repo {repo_id:"SHL"})
#
#    | a
# ---+-------------------------------
#  1 | (n53240:Repo {repo_id:"IQG"})
#
#    | a
# ---+-------------------------------
#  1 | (n53241:Repo {repo_id:"OPF"})
#
#    | a
# ---+-------------------------------
#  1 | (n53242:Repo {repo_id:"PDB"})
#
#    | a
# ---+-------------------------------
#  1 | (n53243:Repo {repo_id:"QEJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53244:Repo {repo_id:"YGD"})
#
#    | a
# ---+-------------------------------
#  1 | (n53245:Repo {repo_id:"ZNE"})
#
#    | a
# ---+-------------------------------
#  1 | (n53246:Repo {repo_id:"OWW"})
#
#    | a
# ---+-------------------------------
#  1 | (n53247:Repo {repo_id:"DHC"})
#
#    | a
# ---+-------------------------------
#  1 | (n53248:Repo {repo_id:"IAB"})
#
#    | a
# ---+-------------------------------
#  1 | (n53249:Repo {repo_id:"JJI"})
#
#    | a
# ---+-------------------------------
#  1 | (n53250:Repo {repo_id:"PAJ"})
#
#    | a
# ---+-------------------------------
#  1 | (n53251:Repo {repo_id:"XIW"})

# %%
##### Create the Has_rated edges, with rating as property #####
tx = graph.cypher.begin()
statement = ("MATCH (u:`Worker`{worker_id:{A}}) "
             "MATCH (m:`Repo`{repo_id:{C}}) MERGE (u)-[r:`Contribution`{contr:{B}}]->(m) RETURN r")

# Looping over ratings
for r,row in df_collaborative.iterrows() :
    # Retrieve "User" and "Movie" nodes, and create relationship with the corresponding rating as property
    tx.append(statement, {"A": row.loc['Worker ID'], "B": row.loc['Coding Effort'], "C": row.loc['Repository ID']})
    if r%100==0 : tx.process()

tx.commit()
# Out:
#    | r
# ---+-------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zxn"})-[r112974:Contribution {contr:69.36}]->(:Repo {repo_id:"EUQ"})
#
#    | r
# ---+--------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zxr"})-[r112975:Contribution {contr:239.97}]->(:Repo {repo_id:"LSY"})
#
#    | r
# ---+-----------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zxv"})-[r112976:Contribution {contr:5.0}]->(:Repo {repo_id:"ECO"})
#
#    | r
# ---+-------------------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zxz"})-[r112977:Contribution {contr:91.98000000000002}]->(:Repo {repo_id:"JJP"})
#
#    | r
# ---+--------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zxz"})-[r112978:Contribution {contr:209.67}]->(:Repo {repo_id:"NHF"})
#
#    | r
# ---+--------------------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zxz"})-[r112979:Contribution {contr:26.440000000000005}]->(:Repo {repo_id:"PUX"})
#
#    | r
# ---+-------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zyt"})-[r112980:Contribution {contr:20.77}]->(:Repo {repo_id:"HEL"})
#
#    | r
# ---+-------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zzc"})-[r112981:Contribution {contr:205.6}]->(:Repo {repo_id:"FHJ"})
#
#    | r
# ---+-------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zzq"})-[r112982:Contribution {contr:52.47}]->(:Repo {repo_id:"DCM"})
#
#    | r
# ---+--------------------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zzr"})-[r112983:Contribution {contr:118.58000000000006}]->(:Repo {repo_id:"CUI"})
#
#    | r
# ---+-------------------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zzr"})-[r112984:Contribution {contr:60.01000000000002}]->(:Repo {repo_id:"LWW"})
#
#    | r
# ---+--------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zzs"})-[r112985:Contribution {contr:330.61}]->(:Repo {repo_id:"XWQ"})
#
#    | r
# ---+-------------------------------------------------------------------------------------------
#  1 | (:Worker {worker_id:"zzu"})-[r112986:Contribution {contr:74.12}]->(:Repo {repo_id:"QCN"})

# %%
graph.cypher.execute('CREATE INDEX ON :Worker(worker_id)')
graph.cypher.execute('CREATE INDEX ON :Repo(repo_id)')

# %% [markdown]
# #### cypher

# %% [markdown]
# find node
# MATCH p=(n:Worker)-[r:Contribution]->(m:Repo) where n.Worker_id='xev' or m.repo_id='VMI' return p

# %% [markdown]
# ### Collaborative Filtering

# %% [markdown]
# ### A. Recommender

# %%
Worker_id = 'xev'
threshold = 0.5
# In Strategy 1, the similarity between two users u1 and u2 is the proportion of movies they have in common
# The score of one given movie m is the proportion of users similar to u1 who rated m

query = (### Similarity normalization : count number of movies seen by u1 ###
  # Count movies rated by u1 as countm
  'MATCH (u1:`Worker` {worker_id:{worker_id}})-[:`Contribution`]->(m1:`Repo`) '
  'WITH count(m1) as countm '
  ### Score normalization : count number of users who are considered similar to u1 ###
  # Retrieve all users u2 who share at least one movie with u1
  'MATCH (u1:`Worker` {worker_id:{worker_id}})-[:`Contribution`]->(m1:`Repo`) '
  'MATCH (m1)<-[r:`Contribution`]-(u2:`Worker`) '
  'WHERE NOT u2=u1 '
  # Compute similarity
  'WITH u2, countm, tofloat(count(r))/countm as sim '
  # Keep users u2 whose similarity with u1 is above some threshold
  'WHERE sim>{threshold} '
  # Count number of similar users as countu
  'WITH count(u2) as countu, countm '
  ### Recommendation ###
  # Retrieve all users u2 who share at least one movie with u1
  'MATCH (u1:`Worker` {worker_id:{worker_id}})-[:`Contribution`]->(m1:`Repo`) '
  'MATCH (m1)<-[r:`Contribution`]-(u2:`Worker`) '
  'WHERE NOT u2=u1 '
  # Compute similarity
  'WITH u1, u2,countu, tofloat(count(r))/countm as sim '
  # Keep users u2 whose similarity with u1 is above some threshold
  'WHERE sim>{threshold} '
  # Retrieve movies m that were rated by at least one similar user, but not by u1
  'MATCH (m:`Repo`)<-[r:`Contribution`]-(u2) '
  'WHERE NOT (m)<-[:`Contribution`]-(u1) '
  # Compute score and return the list of suggestions ordered by score
  'RETURN DISTINCT m, tofloat(count(r))/countu as score1 ORDER BY score1 DESC ')
tx = graph.cypher.begin()
tx.append(query, {'worker_id': Worker_id, 'threshold': threshold})
result = tx.commit()

# %%
result
# Out:
#    | m                             | score1
# ---+-------------------------------+--------
#  1 | (n51873:Repo {repo_id:"VMI"}) |    1.0
#  2 | (n52010:Repo {repo_id:"IDP"}) |    1.0
#  3 | (n52059:Repo {repo_id:"SVV"}) |    1.0
#  4 | (n51986:Repo {repo_id:"AVD"}) |    0.5
#  5 | (n51965:Repo {repo_id:"QEM"}) |    0.5
#  6 | (n51985:Repo {repo_id:"AES"}) |    0.5

# %% [markdown]
# ### B. recommender

# %%
Worker_id = 'xev'
threshold = 0.5

# In Strategy 2, the similarity between two users u1 and u2 is the proportion of movies they have in common
# The score of one movie m is the sum of ratings given by users similar to u1

query = (### Similarity normalization : count number of movies seen by u1 ###
    # Count movies rated by u1 as countm
    'MATCH (m1:`Repo`)<-[:`Contribution`]-(u1:`Worker` {worker_id:{worker_id}}) '
    'WITH count(m1) as countm '
    ### Recommendation ###
    # Retrieve all users u2 who share at least one movie with u1
    'MATCH (u2:`Worker`)-[r2:`Contribution`]->(m1:`Repo`)<-[r1:`Contribution`]-(u1:`Worker` {worker_id:{worker_id}}) '
    'WHERE (NOT u2=u1) '
    # Compute similarity
    'WITH u1, u2, tofloat(count(DISTINCT m1))/countm as sim '
    # Keep users u2 whose similarity with u1 is above some threshold
    'WHERE sim>{threshold} '
    # Retrieve movies m that were rated by at least one similar user, but not by u1
    'MATCH (m:`Repo`)<-[r:`Contribution`]-(u2) '
    'WHERE (NOT (m)<-[:`Contribution`]-(u1)) '
    # Compute score and return the list of suggestions ordered by score
    'RETURN DISTINCT m,tofloat(sum(r.contr)) as score2 ORDER BY score2 DESC ')

tx = graph.cypher.begin()
tx.append(query, {'worker_id': Worker_id, 'threshold': threshold})
result = tx.commit()

# %%
result
# Out:
#    | m                             | score2
# ---+-------------------------------+--------------------
#  1 | (n51873:Repo {repo_id:"VMI"}) |              43.01
#  2 | (n52010:Repo {repo_id:"IDP"}) | 13.360000000000003
#  3 | (n51965:Repo {repo_id:"QEM"}) | 2.4499999999999997
#  4 | (n52059:Repo {repo_id:"SVV"}) | 2.1300000000000003
#  5 | (n51985:Repo {repo_id:"AES"}) |               0.04
#  6 | (n51986:Repo {repo_id:"AVD"}) |                0.0
